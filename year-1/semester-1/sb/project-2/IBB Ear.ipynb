# %%
import os

os.chdir('IBB/yolov8-ears/')

# %%
# INSTALLATION:
# %pip install -r requirements.txt
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%python train.py
# Out:
# 0.0005 0.02 0.0004
# Ultralytics YOLOv8.0.230 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %%python predict.py
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
#
#
# Input image path needed! Defaulting to datasets/ears/images/test/0501.png
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# 0: 480x640 1 ear, 121.7ms
# Speed: 5.2ms preprocess, 121.7ms inference, 1008.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2

# %%
# %%python evaluate.py
# Out:
# UsageError: %%python is a cell magic, but the cell body is empty.
