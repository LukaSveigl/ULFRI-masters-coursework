# %%
from algorithms import *
from evaluators import *
import matplotlib.pyplot as plt
import numpy as np
import warnings

np.random.seed(42)
warnings.filterwarnings("ignore")

# %%
print(ExampleEvaluator().get_params())
ExampleEvaluator().simulate(algo='baseline')
# Out:
# {'alpha1': 34.73, 'alpha2': 49.36, 'alpha3': 32.73, 'alpha4': 49.54, 'delta1': 1.93, 'delta2': 0.69, 'Kd': 10.44, 'n': 4.35}

# %% [markdown]
# ## Optimizations with hyperparameter search

# %% [markdown]
# #### Grey Wolf Optimizer

# %%
gw_param_options = {
    'population': [10, 15]
}

gw_hyper = HyperSearch(GreyWolfOptimizer, GoalEvaluator, is_export=True).execute(**gw_param_options)
print("Hyper parameters", gw_hyper.best_params, "Best seed", gw_hyper.best_seed)
# Out:
# Hyper search start [steps=8]
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# EXPORTING TOP None
# EXPORTING TOP None
#   0%|          | 0/2 [00:00<?, ?it/s]
# EXPORTING TOP None
# Converged after 3
# Hyper parameters {'population': 10} Best seed 42

# %%
gw_evaluator = gw_hyper.optimize_parameters(gw_hyper.best_params['population'], 100, top=1)

print("Evaluation", gw_evaluator.evaluate())
print("Best params", gw_evaluator.get_params())
gw_evaluator.simulate()
# Out:
# [1] Best Fitness: 1500000
# [2] Best Fitness: 1300000
# [4] Best Fitness: 1000000
# [18] Best Fitness: 1406.068045395421
# [29] Best Fitness: 1392.7283389318563
# [33] Best Fitness: 1329.7776014468245
# [43] Best Fitness: 1325.4873643063638
# [48] Best Fitness: 1321.7675676238614
# [49] Best Fitness: 1304.9089038630684
# [90] Best Fitness: 1288.4139400961903
# Best Fitness: 1288.4139400961903
# EXPORTING TOP None
# Evaluation -1288.4139400961903
# Best params {'alpha1': 7.2260295790273155, 'alpha2': 7.2260295790273155, 'alpha3': 7.2260295790273155, 'alpha4': 7.2260295790273155, 'delta1': 0.05443529611401671, 'delta2': 0.05443529611401671, 'Kd': 33.40582587764459, 'n': 1.3402415264843666}

# %% [markdown]
# #### Whale Optimization Algorithm

# %%
woa_param_options = {
    'generations': 15,
    'mutation_strength': np.linspace(0.1, 0.4, 3),
    'population': [10, 15]
}

woa_hyper = HyperSearch(WhaleOptimizationAlgorithm, GoalEvaluator, is_export=True).execute(**woa_param_options)
print("Hyper parameters", woa_hyper.best_params, "Best seed", woa_hyper.best_seed)
# Out:
# Hyper search start [steps=24]
# ...
#   0%|          | 0/6 [00:00<?, ?it/s]
# Converged after 3
# Hyper parameters {'mutation_strength': 0.25, 'population': 10} Best seed 1

# %%
woa_evaluator = woa_hyper.optimize_parameters(woa_hyper.best_params['population'], 200)

print("Evaluation", woa_evaluator.evaluate())
print("Best params", woa_evaluator.get_params())
woa_evaluator.simulate()
# Out:
# [1] Best Fitness: 1500000
# [2] Best Fitness: 1400000
# [3] Best Fitness: 1300000
# [4] Best Fitness: 1000000
# [5] Best Fitness: 234499.89517817023
# [29] Best Fitness: 209804.05291769543
# [53] Best Fitness: 105347.81843132149
# [54] Best Fitness: 27620.67570532348
# [55] Best Fitness: 1499.06123561929
# [71] Best Fitness: 863.2193047698961
# [75] Best Fitness: 630.1574025442845
# [81] Best Fitness: 490.58065433630355
# [85] Best Fitness: 235.22577863576666
# [87] Best Fitness: 206.88097725779292
# [88] Best Fitness: 199.48103925894037
# [89] Best Fitness: 145.59298591065937
# [91] Best Fitness: 89.26119709695563
# [93] Best Fitness: 65.7415208127305
# [94] Best Fitness: 59.83809163408068
# [95] Best Fitness: 40.70762558001442
# [100] Best Fitness: 39.9463095818481
# [101] Best Fitness: 21.76656739200402
# [102] Best Fitness: 12.648097773994062
# [103] Best Fitness: 10.551244260943113
# [104] Best Fitness: 7.182906112269583
# [106] Best Fitness: 6.852700747755677
# ...

# %% [markdown]
# #### Ant Colony Optimization

# %%
ant_param_options = {
    'generations': 10,
    'population': [15, 20],
    'rho': np.linspace(0.1, 0.3, 5),
    'elite_percentage': [0.1, 0.2]
}

#ant_hyper = HyperSearch(AntColonyOptimization, GoalEvaluator).execute(**ant_param_options)
#print("Hyper parameters", ant_hyper.best_params, "Best seed", ant_hyper.best_seed)

# %%
#ant_evaluator = ant_hyper.optimize_parameters(ant_hyper.best_params['population'], 50)

#print("Evaluation", ant_evaluator.evaluate())
#print("Best params", ant_evaluator.get_params())
#ant_evaluator.simulate()

# %% [markdown]
# #### Genetic Algorithm

# %%
ga_param_options = {
    'generations': 10,
    'population': [15, 20],
    'mutation_rate': np.linspace(0.05, 0.5, 4),
    'elite_percentage': [0.15]
}

ga_hyper = HyperSearch(GeneticAlgorithm, GoalEvaluator).execute(**ga_param_options)
print("Hyper parameters", ga_hyper.best_params, "Best seed", ga_hyper.best_seed)
# Out:
# Hyper search start [steps=32]
# ...
#   0%|          | 0/8 [00:00<?, ?it/s]
# Hyper parameters {'elite_percentage': 0.15, 'mutation_rate': 0.5, 'population': 20} Best seed 555

# %%
ga_evaluator = ga_hyper.optimize_parameters(50, 100, seed=12)

print("Evaluation", ga_evaluator.evaluate())
print("Best params", ga_evaluator.get_params())
ga_evaluator.simulate()
# Out:
# [0] Update best with -1300000.00000
# [4] Update best with -1000000.00000
# [21] Update best with -654564.57743
# [25] Update best with -0.00894
# Evaluation -0.008940559381597712
# Best params {'alpha1': 5.168931676215046, 'alpha2': 33.47689434663473, 'alpha3': 25.819007017158995, 'alpha4': 17.49217691007206, 'delta1': 29.66916950866765, 'delta2': 1.9394517901717823, 'Kd': 0.1744525418130607, 'n': 3.8371206598881398}
